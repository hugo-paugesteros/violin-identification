# %%
import numpy as np
import tqdm
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('/home/hugo/Thèse/styles.mplstyle')

import sys
sys.path.append('../src')

# %%
wrong = pd.read_pickle('../models/wrong.pkl')

wrong = wrong.to_frame()
wrong = wrong.groupby('violin')['count'].aggregate('sum')
wrong = wrong.sort_values(ascending=False)

fig, ax = plt.subplots()

wrong.plot.bar(x=wrong.index, y='count')
# Out:
# <Axes: xlabel='violin'>
